# %% [markdown]
# # AUTOMOBILE SALES

# %% [markdown]
# ##### IMPORTING LIBRARIES AND LOADING DATA

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##### LOADING FILE

# %%
df=pd.read_csv(r"D:\DATASCIENCE\MyProjects\proj\Auto Sales data.csv",parse_dates=['ORDERDATE'],dayfirst=True)

# %% [markdown]
# ##### CHECKING SAMPLE OF DATA

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#       ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# 0    2018-02-24                   828   Shipped  Motorcycles    95
# 1    2018-05-07                   757   Shipped  Motorcycles    95
# 2    2018-07-01                   703   Shipped  Motorcycles    95
# 3    2018-08-25                   649   Shipped  Motorcycles    95
# 4    2018-10-28                   586   Shipped  Motorcycles    95
# ...         ...                   ...       ...          ...   ...
# 2742 2019-12-02                  2924   Shipped        Ships    54
# 2743 2020-01-31                  2865   Shipped        Ships    54
# 2744 2020-03-01                  2836  Resolved        Ships    54
# 2745 2020-03-28                  2810   Shipped        Ships    54
# 2746 2020-05-06                  2772   On Hold        Ships    54
#
#      PRODUCTCODE             CUSTOMERNAME             PHONE  \
# 0       S10_1678        Land of Toys Inc.        2125557818
# 1       S10_1678       Reims Collectables        26.47.1555
# 2       S10_1678          Lyon Souveniers  +33 1 46 62 7555
# 3       S10_1678        Toys4GrownUps.com        6265557265
# 4       S10_1678     Technics Stores Inc.        6505556809
# ...          ...                      ...               ...
# 2742    S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2743    S72_3212  Oulu Toy Supplies, Inc.        981-443655
# 2744    S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2745    S72_3212             Alpha Cognac        61.77.6555
# 2746    S72_3212        Gifts4AllAges.com        6175559555
#
#                        ADDRESSLINE1        CITY POSTALCODE  COUNTRY  \
# 0           897 Long Airport Avenue         NYC      10022      USA
# 1                59 rue de l'Abbaye       Reims      51100   France
# 2     27 rue du Colonel Pierre Avia       Paris      75508   France
# 3                78934 Hillside Dr.    Pasadena      90003      USA
# 4                 9408 Furth Circle  Burlingame      94217      USA
# ...                             ...         ...        ...      ...
# 2742             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2743                    Torikatu 38        Oulu      90110  Finland
# 2744             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2745          1 rue Alsace-Lorraine    Toulouse      31000   France
# 2746             8616 Spinnaker Dr.      Boston      51003      USA
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                 Yu             Kwai    Small
# 1            Henriot             Paul    Small
# 2           Da Cunha           Daniel   Medium
# 3              Young            Julie   Medium
# 4             Hirano             Juri   Medium
# ...              ...              ...      ...
# 2742          Freyre            Diego    Small
# 2743       Koskitalo           Pirkko   Medium
# 2744          Freyre            Diego   Medium
# 2745          Roulet          Annette    Small
# 2746         Yoshido             Juri   Medium
#
# [2747 rows x 20 columns]

# %% [markdown]
# ##### DATA PREPROCESSING

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
# std       91.877521         9.762135    42.042549         4.230544
#
#               SALES                      ORDERDATE  DAYS_SINCE_LASTORDER  \
# count   2747.000000                           2747           2747.000000
# mean    3553.047583  2019-05-13 21:56:17.211503360           1757.085912
# min      482.130000            2018-01-06 00:00:00             42.000000
# 25%     2204.350000            2018-11-08 00:00:00           1077.000000
# 50%     3184.800000            2019-06-24 00:00:00           1761.000000
# 75%     4503.095000            2019-11-17 00:00:00           2436.500000
# max    14082.800000            2020-05-31 00:00:00           3562.000000
# std     1838.953901                            NaN            819.280576
#
#               MSRP
# count  2747.000000
# mean    100.691664
# min      33.000000
# 25%      68.000000
# 50%      99.000000
# 75%     124.000000
# max     214.000000
# std      40.114802

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   datetime64[ns]
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
#  15  POSTALCODE            2747 non-null   object
#  16  COUNTRY               2747 non-null   object
#  17  CONTACTLASTNAME       2747 non-null   object
#  18  CONTACTFIRSTNAME      2747 non-null   object
#  19  DEALSIZE              2747 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(12)
# memory usage: 429.3+ KB

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
# std       91.877521         9.762135    42.042549         4.230544
#
#               SALES                      ORDERDATE  DAYS_SINCE_LASTORDER  \
# count   2747.000000                           2747           2747.000000
# mean    3553.047583  2019-05-13 21:56:17.211503360           1757.085912
# min      482.130000            2018-01-06 00:00:00             42.000000
# 25%     2204.350000            2018-11-08 00:00:00           1077.000000
# 50%     3184.800000            2019-06-24 00:00:00           1761.000000
# 75%     4503.095000            2019-11-17 00:00:00           2436.500000
# max    14082.800000            2020-05-31 00:00:00           3562.000000
# std     1838.953901                            NaN            819.280576
#
#               MSRP
# count  2747.000000
# mean    100.691664
# min      33.000000
# 25%      68.000000
# 50%      99.000000
# 75%     124.000000
# max     214.000000
# std      40.114802

# %% [markdown]
# ##### MISSING VALUES

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER             0
# QUANTITYORDERED         0
# PRICEEACH               0
# ORDERLINENUMBER         0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# PRODUCTCODE             0
# CUSTOMERNAME            0
# PHONE                   0
# ADDRESSLINE1            0
# CITY                    0
# POSTALCODE              0
# COUNTRY                 0
# CONTACTLASTNAME         0
# CONTACTFIRSTNAME        0
# DEALSIZE                0
# dtype: int64

# %% [markdown]
# ###### no missing values found

# %% [markdown]
# ##### DUPLICATE VALUES

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###### since ORDERNUMBER is not relevant  for the EDA here ,we will drop it

# %%
df_num = df.select_dtypes(include=['float64', 'int64']).drop(columns=['ORDERNUMBER'])
print(df_num.columns, len(list(df_num.columns.values)))
# Out:
# Index(['QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'SALES',
#        'DAYS_SINCE_LASTORDER', 'MSRP'],
#       dtype='object') 6

# %% [markdown]
# ##### EXTRACT YEARLY, QUARTERLY,MONTHLY,WEEKLY SALES TREND

# %% [markdown]
# ###### EXTRACT YEAR,MONTH,WEEK AND QUARTER FROM ORDERDATE

# %%
df['year']=df['ORDERDATE'].dt.year
df['month']=df['ORDERDATE'].dt.month
df['week']=df['ORDERDATE'].dt.isocalendar().week
df['quarter']=df['ORDERDATE'].dt.quarter

# %% [markdown]
# ##### SALES TREND BY YEAR

# %%
sns.set(style='whitegrid',rc={"figure.figsize":(20,5)})
sns.lineplot(data=df,x='ORDERDATE',y='SALES',ci=None,hue='year',palette=sns.color_palette("husl",len(df['year'].unique())))
plt.title("Sales Trend by Year")
plt.xlabel("year",fontsize=10)
plt.ylabel("sales",fontsize=10)
plt.legend(title='year',loc='best')
plt.show()
# Out:
# C:\Users\Anandhu Subramanian\AppData\Local\Temp\ipykernel_17652\3085954441.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df,x='ORDERDATE',y='SALES',ci=None,hue='year',palette=sns.color_palette("husl",len(df['year'].unique())))

# %% [markdown]
# ##### SALES TREND BY QUARTER

# %%
sns.set(style='whitegrid',rc={"figure.figsize":(20,5)})
sns.lineplot(data=df,x='quarter',y='SALES',ci=None,hue='year',palette=sns.color_palette("husl",len(df['year'].unique())))
plt.title("SALES TREND BY QUARTER")
plt.xlabel("Quarter",fontsize=10)
plt.ylabel('Sales',fontsize=10)
plt.legend(title='year',loc='best')
plt.show()
# Out:
# C:\Users\Anandhu Subramanian\AppData\Local\Temp\ipykernel_17652\1115639288.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df,x='quarter',y='SALES',ci=None,hue='year',palette=sns.color_palette("husl",len(df['year'].unique())))

# %% [markdown]
# ##### SALES TREND BY MONTH

# %%
sns.set(style="whitegrid", rc={"figure.figsize": (20, 5)})
sns.lineplot(data=df, x="month", y="SALES", ci=None, hue="year",palette=sns.color_palette("husl", len(df['year'].unique())))
plt.title("Sales Trend by Month")
plt.xlabel("Month", fontsize=10)
plt.ylabel("SALES", fontsize=10)
plt.legend(title="Year", loc='best')
plt.show()
# Out:
# C:\Users\Anandhu Subramanian\AppData\Local\Temp\ipykernel_17652\3434071151.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x="month", y="SALES", ci=None, hue="year",palette=sns.color_palette("husl", len(df['year'].unique())))

# %% [markdown]
# ##### SALES TREND BY WEEK

# %%
sns.set(style="whitegrid", rc={"figure.figsize": (20, 5)})
sns.lineplot(data=df, x="week", y="SALES", ci=None, hue="year", palette=sns.color_palette("husl", len(df['year'].unique())))
plt.title("Sales Trend by Week")
plt.xlabel("Week", fontsize=10)
plt.ylabel("SALES", fontsize=10)
plt.legend(title="Year", loc='best')
plt.show()
# Out:
# C:\Users\Anandhu Subramanian\AppData\Local\Temp\ipykernel_17652\842403514.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x="week", y="SALES", ci=None, hue="year", palette=sns.color_palette("husl", len(df['year'].unique())))

# %% [markdown]
# ##### DISCRIPTION OF QUANTITYORDERED

# %%
df['QUANTITYORDERED'].describe()
# Out:
# count    2747.000000
# mean       35.103021
# std         9.762135
# min         6.000000
# 25%        27.000000
# 50%        35.000000
# 75%        43.000000
# max        97.000000
# Name: QUANTITYORDERED, dtype: float64

# %% [markdown]
# ##### HISTOGRAM OF QUANTITY ORDERED

# %%
       
def univariateAnalysis_numeric(column, nbins):
    print("Description of " + column)
   
    print(df[column].describe(), end=' ')
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    # Plot histogram
    
    sns.histplot(df[column], bins=nbins, kde=True, ax=axes[0])
    axes[0].set_title("Histogram of " + column)
    # Plot violin plot
   
    sns.boxplot(x=df[column], ax=axes[1])
    axes[1].set_title("Boxlot of " + column )
    plt.show()
for x in df_num:
    univariateAnalysis_numeric(x,20)
# Out:
# Description of QUANTITYORDERED
# count    2747.000000
# mean       35.103021
# std         9.762135
# min         6.000000
# 25%        27.000000
# 50%        35.000000
# 75%        43.000000
# max        97.000000
# Name: QUANTITYORDERED, dtype: float64
# Description of PRICEEACH
# count    2747.000000
# mean      101.098952
# std        42.042549
# min        26.880000
# 25%        68.745000
# 50%        95.550000
# 75%       127.100000
# max       252.870000
# Name: PRICEEACH, dtype: float64
# Description of ORDERLINENUMBER
# count    2747.000000
# mean        6.491081
# std         4.230544
# min         1.000000
# 25%         3.000000
# 50%         6.000000
# 75%         9.000000
# max        18.000000
# Name: ORDERLINENUMBER, dtype: float64
# Description of SALES
# count     2747.000000
# mean      3553.047583
# std       1838.953901
# min        482.130000
# 25%       2204.350000
# 50%       3184.800000
# 75%       4503.095000
# max      14082.800000
# Name: SALES, dtype: float64
# Description of DAYS_SINCE_LASTORDER
# count    2747.000000
# mean     1757.085912
# std       819.280576
# min        42.000000
# 25%      1077.000000
# 50%      1761.000000
# 75%      2436.500000
# max      3562.000000
# Name: DAYS_SINCE_LASTORDER, dtype: float64
# Description of MSRP
# count    2747.000000
# mean      100.691664
# std        40.114802
# min        33.000000
# 25%        68.000000
# 50%        99.000000
# 75%       124.000000
# max       214.000000
# Name: MSRP, dtype: float64

# %% [markdown]
# ##### Comparison between Quantity Ordered, Product Line along with Dealsize as Hue

# %%
sns.set(style="white", rc={"figure.figsize": (15, 5)})
sns.barplot(data=df, x="PRODUCTLINE", y="QUANTITYORDERED", hue="DEALSIZE", palette="Set2", ci=None)
plt.ylabel("QUANTITY ORDERED", fontsize=10)
plt.xlabel("Product Line", fontsize=10)
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.1f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom',fontsize=8)
plt.legend(title="Deal Size", fontsize=10, loc="upper left", bbox_to_anchor=(1, 1))
plt.show()
# Out:
# C:\Users\Anandhu Subramanian\AppData\Local\Temp\ipykernel_17652\3135724708.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="PRODUCTLINE", y="QUANTITYORDERED", hue="DEALSIZE", palette="Set2", ci=None)

# %% [markdown]
# ##### Comparision between Quantity Ordered, Product Line along with Dealsize as Hue

# %%
sns.set(style="white", rc={"figure.figsize": (15, 5)})
sns.barplot(data=df, x="PRODUCTLINE", y="PRICEEACH", hue="DEALSIZE", palette="Set2", ci=None)
plt.ylabel("PRICE EACH", fontsize=10)
plt.xlabel("Product Line", fontsize=10)
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.1f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom',fontsize=8)
plt.legend(title="Deal Size",fontsize=10,  loc="upper left", bbox_to_anchor=(1, 1))
plt.show()
# Out:
# C:\Users\Anandhu Subramanian\AppData\Local\Temp\ipykernel_17652\3165246470.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="PRODUCTLINE", y="PRICEEACH", hue="DEALSIZE", palette="Set2", ci=None)

# %% [markdown]
# ##### Comparision between Quantity Ordered, Product Line along with Dealsize as Hue

# %%
sns.set(style="white", rc={"figure.figsize": (15, 5)})
sns.barplot(data=df, x="PRODUCTLINE", y="MSRP", hue="DEALSIZE", palette="Set2", ci=None)
plt.ylabel("MSRP", fontsize=10)
plt.xlabel("Product Line", fontsize=10)
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.1f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom',fontsize=8)
plt.legend(title="Deal Size",fontsize=10,  loc="upper left", bbox_to_anchor=(1, 1))
plt.show()
# Out:
# C:\Users\Anandhu Subramanian\AppData\Local\Temp\ipykernel_17652\1338735886.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="PRODUCTLINE", y="MSRP", hue="DEALSIZE", palette="Set2", ci=None)

# %% [markdown]
# ##### YEARLY SALES

# %%
sns.set(style="white", rc={"figure.figsize": (15, 5)})
sns.barplot(data=df, x="PRODUCTLINE", y="SALES", hue="year",  errorbar=None)
plt.xlabel("Product Line", fontsize=10)
plt.ylabel("Sales(K)", fontsize=10)
plt.title("Yearly Sales", fontsize=10)
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.1f}K', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom',fontsize=8)
plt.legend(title="Year",fontsize=10,  loc="upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ##### YEARLY SALE COMPARED TO DEALSIZE

# %%
sns.set(style="white", rc={"figure.figsize": (15, 5)})
sns.barplot(data=df, x="DEALSIZE", y="SALES", hue="year",  ci=None)
plt.xlabel("Deal Size", fontsize=10)
plt.ylabel("Sales(K)", fontsize=10)
plt.title("Yearly Sales", fontsize=12)
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.1f}K', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom',fontsize=8)
plt.legend(title="Year",fontsize=10,  loc="upper left", bbox_to_anchor=(1, 1))
plt.show()
# Out:
# C:\Users\Anandhu Subramanian\AppData\Local\Temp\ipykernel_17652\2812089864.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="DEALSIZE", y="SALES", hue="year",  ci=None)

# %% [markdown]
# ##### PIE PLOT FOR PRODUCTLINE

# %%
plt.pie(df["PRODUCTLINE"].value_counts(),labels=df["PRODUCTLINE"].unique(),autopct="%.2f",explode=[0.1,0.1,0.01,0,0,0,0],shadow=True)
plt.show()

# %% [markdown]
# ##### PIE PLOT FOR DEALSIZE

# %%
plt.pie(df["DEALSIZE"].value_counts(),labels=df["DEALSIZE"].unique(),autopct="%.2f",explode=[0.01,0,0.3],shadow=True)
plt.show()

# %% [markdown]
# ##### GROUPING COUNTRY AND QUANTITY ORDERED

# %%
colors=plt.cm.plasma(np.linspace(.7, .3, 20))

plt.figure(figsize=(10,5))
df.groupby("COUNTRY")["QUANTITYORDERED"].agg("sum").plot(kind="bar",color=colors)
plt.show()

# %% [markdown]
# ##### GROUPING PRODUCTLINE AND QUANTITYORDERED

# %%
colors=plt.cm.magma(np.linspace(.1, .6, 7))

plt.figure(figsize=(10,5))
df.groupby("PRODUCTLINE")["QUANTITYORDERED"].agg("sum").plot(kind="bar",color=colors)
plt.show()

# %% [markdown]
# ##### COUNT OF COUNRTY,PRODUCTLINE AND QUANTITYORDERED ALONG WITH DEALSIZE

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(7, 13))

colors=plt.cm.magma(np.linspace(.1, .9, 20))

# Plot on the country
df.groupby("COUNTRY")["DEALSIZE"].count().plot(kind="bar",color=colors, ax=axes[0])
axes[0].set_title('Count of COUNTRY by DEALSIZE')
axes[0].legend()

#plot on quantityordered
colors=plt.cm.magma(np.linspace(.4, .9, 3))
df.groupby("DEALSIZE")["QUANTITYORDERED"].median().plot(kind="bar",color=colors, ax=axes[2])
axes[2].set_title('Count of QUANTITY ORDERED by DEALSIZE')
axes[2].legend()


colors=plt.cm.viridis(np.linspace(.4, .9, 7))
# Plot on the second subplot
df.groupby("PRODUCTLINE")["DEALSIZE"].count().plot(kind="bar",color=colors, ax=axes[1])
axes[1].set_title('Count of PRODUCTLINE by DEALSIZE')
axes[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### CONCLUSION OF THE EXPLORATORY DATA ANALYSIS

# %% [markdown]
# #### 298 orders placed by 89 customers fromo 19 countries in last 2.5 years

# %% [markdown]
# ##### Upward sales trend with monthly seasonality. Peak sales in October and November annually.

# %% [markdown]
# ##### Higher sales and customer activity in the early months of 2020 compared to previous years.

# %% [markdown]
# ##### Most deals are of medium and small size, with transactions typically containing 20 to 50 items.

# %% [markdown]
# ##### Significant sales increase observed in US and France in 2019.

# %% [markdown]
# ##### United States leads in sales, followed by Spain and France. Notable sales from Australia and Singapore in the Eastern Hemisphere.

# %% [markdown]
# ##### Car, Truck, Bus, and Motorcycle parts account for 80% of the company's revenue.

# %% [markdown]
# ##### Most deals are of medium and small size, with transactions typically containing 20 to 50 items
